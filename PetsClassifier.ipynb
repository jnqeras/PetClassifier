# %% [markdown]
# <a href="https://colab.research.google.com/github/jnqeras/PetClassifier/blob/main/PetsClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lesson 1 - What's your pet

# %% [markdown]
# Welcome to lesson 1! For those of you who are using a Jupyter Notebook for the first time, you can learn about this useful tool in a tutorial we prepared specially for you; click `File`->`Open` now and click `00_notebook_tutorial.ipynb`.
#
# In this lesson we will build our first image classifier from scratch, and see if we can achieve world-class results. Let's dive in!
#
# Every notebook starts with the following three lines; they ensure that any edits to libraries you make are reloaded here automatically, and also that any charts or images displayed are shown in this notebook.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# We import all the necessary packages. We are going to work with the [fastai V1 library](http://www.fast.ai/2018/10/02/fastai-ai/) which sits on top of [Pytorch 1.0](https://hackernoon.com/pytorch-1-0-468332ba5163). The fastai library provides many useful functions that enable us to quickly and easily build neural networks and train our models.

# %%
from fastai.vision import *
from fastai.metrics import *

# %% [markdown]
# If you're using a computer with an unusually small GPU, you may get an out of memory error when running this notebook. If this happens, click Kernel->Restart, uncomment the 2nd line below to use a smaller *batch size* (you'll learn all about what this means during the course), and try again.

# %%
bs = 64
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# ## Looking at the data

# %% [markdown]
# We are going to use the [Oxford-IIIT Pet Dataset](http://www.robots.ox.ac.uk/~vgg/data/pets/) by [O. M. Parkhi et al., 2012](http://www.robots.ox.ac.uk/~vgg/publications/2012/parkhi12a/parkhi12a.pdf) which features 12 cat breeds and 25 dogs breeds. Our model will need to learn to differentiate between these 37 distinct categories. According to their paper, the best accuracy they could get in 2012 was 59.21%, using a complex model that was specific to pet detection, with separate "Image", "Head", and "Body" models for the pet photos. Let's see how accurate we can be using deep learning!
#
# We are going to use the `untar_data` function to which we must pass a URL as an argument and which will download and extract the data.

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.datasets:
#
# untar_data(url:str, fname:Union[pathlib.Path, str]=None, dest:Union[pathlib.Path, str]=None, data=True, force_download=False) -> pathlib.Path
#     Download `url` to `fname` if `dest` doesn't exist, and un-tgz to folder `dest`.

# %%
path = untar_data(URLs.PETS); path
# Out:
# PosixPath('/root/.fastai/data/oxford-iiit-pet')

# %%
 path.ls()
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/annotations')]

# %%
path_anno = path/'annotations'
path_img = path/'images'

# %% [markdown]
# The first thing we do when we approach a problem is to take a look at the data. We _always_ need to understand very well what the problem is and what the data looks like before we can figure out how to solve it. Taking a look at the data means understanding how the data directories are structured, what the labels are and what some sample images look like.
#
# The main difference between the handling of image classification datasets is the way labels are stored. In this particular dataset, labels are stored in the filenames themselves. We will need to extract them to be able to classify the images into the correct categories. Fortunately, the fastai library has a handy function made exactly for this, `ImageDataBunch.from_name_re` gets the labels from the filenames using a [regular expression](https://docs.python.org/3.6/library/re.html).

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_116.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_45.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_90.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/newfoundland_70.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_184.jpg')]

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'

# %%
  data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs
                                  ).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']
# (37, 37)

# %% [markdown]
# *italicized text*## Training: resnet34

# %% [markdown]
# Now we will start training our model. We will use a [convolutional neural network](http://cs231n.github.io/convolutional-networks/) backbone and a fully connected head with a single hidden layer as a classifier. Don't know what these things mean? Not to worry, we will dive deeper in the coming lessons. For the moment you need to know that we are building a model which will take images as input and will output the predicted probability for each of the categories (in this case, it will have 37 outputs).
#
# We will train for 4 epochs (4 cycles through all our data).

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.380689</td>
#       <td>0.304254</td>
#       <td>0.104871</td>
#       <td>01:36</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.619969</td>
#       <td>0.246097</td>
#       <td>0.087957</td>
#       <td>01:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.386313</td>
#       <td>0.216007</td>
#       <td>0.066306</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.287448</td>
#       <td>0.199254</td>
#       <td>0.064276</td>
#       <td>01:40</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ###Lo siguiente guarda los weights de lo que corrí antes.

# %%
learn.save('stage-1')

# %% [markdown]
# ## Results

# %% [markdown]
# Let's see what results we have got.
#
# We will first see which were the categories that the model most confused with one another. We will try to see if what the model predicted was reasonable or not. In this case the mistakes look reasonable (none of the mistakes seems obviously naive). This is an indicator that our classifier is working correctly.
#
# Furthermore, when we plot the confusion matrix, we can see that the distribution is heavily skewed: the model makes the same mistakes over and over again but it rarely confuses other categories. This suggests that it just finds it difficult to distinguish some specific categories between each other; this is normal behaviour.

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a7fe6964f6f7> in <module>()
# ----> 1 doc(interp.plot_top_losses)
#
# NameError: name 'doc' is not defined

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Ragdoll', 'Birman', 8),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 7),
#  ('British_Shorthair', 'Russian_Blue', 4),
#  ('american_bulldog', 'american_pit_bull_terrier', 4),
#  ('Egyptian_Mau', 'Bengal', 3),
#  ('Maine_Coon', 'Ragdoll', 3),
#  ('Persian', 'British_Shorthair', 3),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 3),
#  ('basset_hound', 'beagle', 3),
#  ('boxer', 'american_bulldog', 3),
#  ('miniature_pinscher', 'chihuahua', 3),
#  ('Birman', 'Siamese', 2),
#  ('Maine_Coon', 'Abyssinian', 2),
#  ('Siamese', 'Birman', 2),
#  ('american_pit_bull_terrier', 'american_bulldog', 2),
#  ('chihuahua', 'Sphynx', 2),
#  ('yorkshire_terrier', 'havanese', 2)]

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.675162</td>
#       <td>0.315549</td>
#       <td>0.092016</td>
#       <td>01:54</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ####Acá vuelve a cargar los parámetros que guardó arriba en 'stage-1'.

# %%
learn.load('stage-1');

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='59' class='' max='92', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       64.13% [59/92 00:58<00:32 0.8904]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %% [markdown]
# ####Hacer shift+tab parado a la izq de max_lr

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.233287</td>
#       <td>0.202120</td>
#       <td>0.062246</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.233000</td>
#       <td>0.192914</td>
#       <td>0.062923</td>
#       <td>01:39</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# That's a pretty accurate model!

# %% [markdown]
# ## Training: resnet50

# %% [markdown]
# Now we will train in the same way as before but with one caveat: instead of using resnet34 as our backbone we will use resnet50 (resnet34 is a 34 layer residual network while resnet50 has 50 layers. It will be explained later in the course and you can learn the details in the [resnet paper](https://arxiv.org/pdf/1512.03385.pdf)).
#
# Basically, resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here. To help it along, let's us use larger images too, since that way the network can see more detail. We reduce the batch size a bit since otherwise this larger network will require more GPU memory.

# %%
  data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(),
                                    size=299, bs=bs//2).normalize(imagenet_stats)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(IntProgress(value=0, max=102502400), HTML(value='')))

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='58' class='' max='92', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       63.04% [58/92 00:55<00:32 0.7072]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.307465</td>
#       <td>0.288348</td>
#       <td>0.097429</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.591981</td>
#       <td>0.819586</td>
#       <td>0.216509</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.619849</td>
#       <td>0.771742</td>
#       <td>0.194858</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.498587</td>
#       <td>0.484118</td>
#       <td>0.131935</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.355543</td>
#       <td>0.434261</td>
#       <td>0.117050</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.204300</td>
#       <td>0.269186</td>
#       <td>0.072395</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.103746</td>
#       <td>0.260020</td>
#       <td>0.067659</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.077638</td>
#       <td>0.251637</td>
#       <td>0.065629</td>
#       <td>01:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-50')

# %% [markdown]
# It's astonishing that it's possible to recognize pet breeds so accurately! Let's see if full fine-tuning helps:

# %%
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.695497</td>
#       <td>0.531125</td>
#       <td>0.146143</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.972999</td>
#       <td>0.286194</td>
#       <td>0.079161</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.614908</td>
#       <td>0.272462</td>
#       <td>0.079161</td>
#       <td>01:55</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# If it doesn't, you can always go back to your previous model.

# %%
learn.load('stage-1-50');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.most_confused(min_val=2)
# Out:
# [('keeshond', 'Persian', 31),
#  ('British_Shorthair', 'scottish_terrier', 30),
#  ('newfoundland', 'scottish_terrier', 30),
#  ('basset_hound', 'yorkshire_terrier', 27),
#  ('Russian_Blue', 'scottish_terrier', 23),
#  ('Sphynx', 'leonberger', 23),
#  ('german_shorthaired', 'english_setter', 23),
#  ('wheaten_terrier', 'english_setter', 23),
#  ('Bombay', 'scottish_terrier', 22),
#  ('Ragdoll', 'British_Shorthair', 22),
#  ('beagle', 'yorkshire_terrier', 22),
#  ('miniature_pinscher', 'scottish_terrier', 22),
#  ('Siamese', 'leonberger', 19),
#  ('japanese_chin', 'leonberger', 18),
#  ('Egyptian_Mau', 'scottish_terrier', 17),
#  ('american_bulldog', 'english_setter', 17),
#  ('havanese', 'leonberger', 17),
#  ('pomeranian', 'Persian', 17),
#  ('shiba_inu', 'Persian', 17),
#  ('american_bulldog', 'yorkshire_terrier', 16),
#  ('pomeranian', 'leonberger', 16),
#  ('Abyssinian', 'scottish_terrier', 15),
#  ('Bengal', 'scottish_terrier', 15),
#  ('Persian', 'scottish_terrier', 15),
#  ('yorkshire_terrier', 'scottish_terrier', 15),
#  ('boxer', 'scottish_terrier', 14),
#  ('miniature_pinscher', 'yorkshire_terrier', 14),
#  ('scottish_terrier', 'leonberger', 14),
#  ('shiba_inu', 'leonberger', 14),
#  ('chihuahua', 'yorkshire_terrier', 13),
#  ('saint_bernard', 'yorkshire_terrier', 13),
#  ('scottish_terrier', 'Siamese', 13),
#  ('Birman', 'British_Shorthair', 12),
#  ('Persian', 'British_Shorthair', 12),
#  ('basset_hound', 'leonberger', 12),
#  ('boxer', 'yorkshire_terrier', 12),
#  ('chihuahua', 'Persian', 12),
#  ('chihuahua', 'leonberger', 12),
#  ('english_cocker_spaniel', 'leonberger', 12),
#  ('samoyed', 'Persian', 12),
#  ('american_pit_bull_terrier', 'english_setter', 11),
#  ('leonberger', 'english_setter', 11),
#  ('saint_bernard', 'english_setter', 11),
#  ('samoyed', 'leonberger', 11),
#  ('staffordshire_bull_terrier', 'english_setter', 11),
#  ('Maine_Coon', 'British_Shorthair', 10),
#  ('newfoundland', 'leonberger', 10),
#  ('pug', 'scottish_terrier', 10),
#  ('yorkshire_terrier', 'leonberger', 10),
#  ('Bengal', 'yorkshire_terrier', 9),
#  ('Birman', 'scottish_terrier', 9),
#  ('Maine_Coon', 'leonberger', 9),
#  ('Maine_Coon', 'scottish_terrier', 9),
#  ('great_pyrenees', 'english_setter', 9),
#  ('havanese', 'scottish_terrier', 9),
#  ('leonberger', 'yorkshire_terrier', 9),
#  ('Birman', 'leonberger', 8),
#  ('Persian', 'beagle', 8),
#  ('american_pit_bull_terrier', 'leonberger', 8),
#  ('english_cocker_spaniel', 'english_setter', 8),
#  ('great_pyrenees', 'leonberger', 8),
#  ('scottish_terrier', 'British_Shorthair', 8),
#  ('staffordshire_bull_terrier', 'yorkshire_terrier', 8),
#  ('Bombay', 'British_Shorthair', 7),
#  ('Ragdoll', 'scottish_terrier', 7),
#  ('german_shorthaired', 'scottish_terrier', 7),
#  ('japanese_chin', 'Abyssinian', 7),
#  ('keeshond', 'leonberger', 7),
#  ('pomeranian', 'scottish_terrier', 7),
#  ('pug', 'Maine_Coon', 7),
#  ('staffordshire_bull_terrier', 'scottish_terrier', 7),
#  ('wheaten_terrier', 'shiba_inu', 7),
#  ('Abyssinian', 'english_setter', 6),
#  ('Siamese', 'scottish_terrier', 6),
#  ('american_pit_bull_terrier', 'scottish_terrier', 6),
#  ('english_setter', 'yorkshire_terrier', 6),
#  ('leonberger', 'scottish_terrier', 6),
#  ('pug', 'leonberger', 6),
#  ('Abyssinian', 'leonberger', 5),
#  ('Bengal', 'leonberger', 5),
#  ('Egyptian_Mau', 'english_setter', 5),
#  ('Ragdoll', 'leonberger', 5),
#  ('Sphynx', 'Persian', 5),
#  ('american_bulldog', 'scottish_terrier', 5),
#  ('english_cocker_spaniel', 'yorkshire_terrier', 5),
#  ('english_setter', 'leonberger', 5),
#  ('great_pyrenees', 'Bombay', 5),
#  ('great_pyrenees', 'yorkshire_terrier', 5),
#  ('japanese_chin', 'chihuahua', 5),
#  ('shiba_inu', 'Bombay', 5),
#  ('Bengal', 'english_setter', 4),
#  ('Egyptian_Mau', 'British_Shorthair', 4),
#  ('Egyptian_Mau', 'leonberger', 4),
#  ('Egyptian_Mau', 'yorkshire_terrier', 4),
#  ('Maine_Coon', 'Bombay', 4),
#  ('Persian', 'Siamese', 4),
#  ('Ragdoll', 'yorkshire_terrier', 4),
#  ('Sphynx', 'english_setter', 4),
#  ('Sphynx', 'yorkshire_terrier', 4),
#  ('boxer', 'Sphynx', 4),
#  ('boxer', 'english_setter', 4),
#  ('english_cocker_spaniel', 'scottish_terrier', 4),
#  ('english_setter', 'chihuahua', 4),
#  ('german_shorthaired', 'Sphynx', 4),
#  ('german_shorthaired', 'leonberger', 4),
#  ('german_shorthaired', 'yorkshire_terrier', 4),
#  ('great_pyrenees', 'Persian', 4),
#  ('great_pyrenees', 'scottish_terrier', 4),
#  ('havanese', 'chihuahua', 4),
#  ('havanese', 'english_setter', 4),
#  ('japanese_chin', 'Sphynx', 4),
#  ('pug', 'beagle', 4),
#  ('pug', 'english_setter', 4),
#  ('saint_bernard', 'Bombay', 4),
#  ('scottish_terrier', 'Persian', 4),
#  ('staffordshire_bull_terrier', 'leonberger', 4),
#  ('wheaten_terrier', 'scottish_terrier', 4),
#  ('yorkshire_terrier', 'Abyssinian', 4),
#  ('Abyssinian', 'British_Shorthair', 3),
#  ('Bengal', 'British_Shorthair', 3),
#  ('Maine_Coon', 'yorkshire_terrier', 3),
#  ('Ragdoll', 'english_setter', 3),
#  ('Russian_Blue', 'english_setter', 3),
#  ('Russian_Blue', 'leonberger', 3),
#  ('Russian_Blue', 'yorkshire_terrier', 3),
#  ('Siamese', 'Persian', 3),
#  ('Siamese', 'pomeranian', 3),
#  ('Siamese', 'yorkshire_terrier', 3),
#  ('american_bulldog', 'Maine_Coon', 3),
#  ('american_bulldog', 'Persian', 3),
#  ('american_bulldog', 'Sphynx', 3),
#  ('american_bulldog', 'pomeranian', 3),
#  ('beagle', 'scottish_terrier', 3),
#  ('chihuahua', 'english_setter', 3),
#  ('great_pyrenees', 'shiba_inu', 3),
#  ('havanese', 'Maine_Coon', 3),
#  ('havanese', 'yorkshire_terrier', 3),
#  ('japanese_chin', 'British_Shorthair', 3),
#  ('keeshond', 'chihuahua', 3),
#  ('keeshond', 'english_setter', 3),
#  ('samoyed', 'Bombay', 3),
#  ('shiba_inu', 'scottish_terrier', 3),
#  ('shiba_inu', 'yorkshire_terrier', 3),
#  ('staffordshire_bull_terrier', 'Persian', 3),
#  ('yorkshire_terrier', 'chihuahua', 3),
#  ('Abyssinian', 'yorkshire_terrier', 2),
#  ('Birman', 'yorkshire_terrier', 2),
#  ('Bombay', 'leonberger', 2),
#  ('British_Shorthair', 'beagle', 2),
#  ('British_Shorthair', 'english_setter', 2),
#  ('Ragdoll', 'Bombay', 2),
#  ('Ragdoll', 'Siamese', 2),
#  ('Ragdoll', 'beagle', 2),
#  ('Siamese', 'British_Shorthair', 2),
#  ('american_pit_bull_terrier', 'Maine_Coon', 2),
#  ('american_pit_bull_terrier', 'english_cocker_spaniel', 2),
#  ('american_pit_bull_terrier', 'shiba_inu', 2),
#  ('american_pit_bull_terrier', 'yorkshire_terrier', 2),
#  ('basset_hound', 'chihuahua', 2),
#  ('basset_hound', 'english_setter', 2),
#  ('beagle', 'Abyssinian', 2),
#  ('boxer', 'Persian', 2),
#  ('boxer', 'beagle', 2),
#  ('boxer', 'pomeranian', 2),
#  ('chihuahua', 'Maine_Coon', 2),
#  ('chihuahua', 'Sphynx', 2),
#  ('chihuahua', 'scottish_terrier', 2),
#  ('great_pyrenees', 'Maine_Coon', 2),
#  ('japanese_chin', 'Maine_Coon', 2),
#  ('japanese_chin', 'beagle', 2),
#  ('japanese_chin', 'pomeranian', 2),
#  ('japanese_chin', 'scottish_terrier', 2),
#  ('leonberger', 'Persian', 2),
#  ('miniature_pinscher', 'Persian', 2),
#  ('newfoundland', 'chihuahua', 2),
#  ('pomeranian', 'yorkshire_terrier', 2),
#  ('pug', 'Persian', 2),
#  ('saint_bernard', 'chihuahua', 2),
#  ('saint_bernard', 'leonberger', 2),
#  ('saint_bernard', 'pomeranian', 2),
#  ('samoyed', 'yorkshire_terrier', 2)]

# %% [markdown]
# ## Other data formats

# %%
path = untar_data(URLs.MNIST_SAMPLE); path
# Out:
# Downloading http://files.fast.ai/data/examples/mnist_sample
# PosixPath('/root/.fastai/data/mnist_sample')

# %%
tfms = get_transforms(do_flip=False)
data = ImageDataBunch.from_folder(path, ds_tfms=tfms, size=26)

# %%
data.show_batch(rows=3, figsize=(5,5))

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy)
learn.fit(2)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# HBox(children=(IntProgress(value=0, max=46827520), HTML(value='')))
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 00:21<00:21]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.200927</td>
#       <td>0.091936</td>
#       <td>0.970559</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='36' class='' max='193', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       18.65% [36/193 00:03<00:16 0.1881]
#     </div>

# %%
df = pd.read_csv(path/'labels.csv')
df.head()

# %%
data = ImageDataBunch.from_csv(path, ds_tfms=tfms, size=28)

# %%
data.show_batch(rows=3, figsize=(5,5))
data.classes

# %%
data = ImageDataBunch.from_df(path, df, ds_tfms=tfms, size=24)
data.classes

# %%
fn_paths = [path/name for name in df['name']]; fn_paths[:2]

# %%
pat = r"/(\d)/\d+\.png$"
data = ImageDataBunch.from_name_re(path, fn_paths, pat=pat, ds_tfms=tfms, size=24)
data.classes

# %%
data = ImageDataBunch.from_name_func(path, fn_paths, ds_tfms=tfms, size=24,
        label_func = lambda x: '3' if '/3/' in str(x) else '7')
data.classes

# %%
labels = [('3' if '/3/' in str(x) else '7') for x in fn_paths]
labels[:5]

# %%
data = ImageDataBunch.from_lists(path, fn_paths, labels=labels, ds_tfms=tfms, size=24)
data.classes
